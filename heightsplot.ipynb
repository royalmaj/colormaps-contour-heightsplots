# %% [markdown]
# <a href="https://colab.research.google.com/github/royalmaj/colormaps-contour-heightsplots/blob/main/heightsplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Create a random DataFrame
data = pd.DataFrame(np.random.rand(10, 10))

# Create X and Y coordinates
X = np.arange(data.shape[0])
Y = np.arange(data.shape[1])

# Create a meshgrid
X, Y = np.meshgrid(X, Y)

# Create a 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Use the 'virdis' colormap
ax.plot_surface(X, Y, data.values, cmap='viridis')
# Show the plot
plt.show()
